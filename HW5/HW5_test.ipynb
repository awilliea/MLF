# %%
import numpy as np
from sklearn import svm

# %%
x = [[1,0],[0,1],[0,-1],[-1,0],[0,2],[0,-2],[-2,0]]
y = [-1,-1,-1,1,1,1,1]

# %%
clf = svm.SVC(C=1e100, kernel='poly', degree=2, gamma=1, coef0=1)

# %%
clf.fit(x,y)
# Out:
# SVC(C=1e+100, cache_size=200, class_weight=None, coef0=1,
#   decision_function_shape='ovr', degree=2, gamma=1, kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
print (clf.dual_coef_ )       #支持向量的系数，公式中的alpha
print (clf.support_vectors_)   #支持向量
print (clf.intercept_)         #截距，公式中的b
# Out:
# [[-0.59647182 -0.81065085  0.8887034   0.20566488  0.31275439]]
# [[ 0.  1.]
#  [ 0. -1.]
#  [-1.  0.]
#  [ 0.  2.]
#  [ 0. -2.]]
# [-1.66633088]
